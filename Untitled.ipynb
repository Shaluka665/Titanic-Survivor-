# %% [markdown]
# # TITANIC SURVIVOR

# %% [markdown]
# ### To check the number of survivor on different parameter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
fig = plt.figure(figsize=(18,6))

# %%
train.Survived.value_counts(normalize=True).plot(kind="bar",alpha = 0.5)

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['survived','dead']
    df.plot(kind = 'bar' , figsize = (10,5))

# %%
bar_chart('Sex')

# %% [markdown]
# #### To check the details of a particular person

# %%
test.set_index('Name', inplace=True)

# %%
test
# Out:
#                                               PassengerId  Pclass     Sex  \
# Name
# Kelly, Mr. James                                      892       3    male
# Wilkes, Mrs. James (Ellen Needs)                      893       3  female
# Myles, Mr. Thomas Francis                             894       2    male
# Wirz, Mr. Albert                                      895       3    male
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  female
# ...                                                   ...     ...     ...
# Spector, Mr. Woolf                                   1305       3    male
# Oliva y Ocana, Dona. Fermina                         1306       1  female
# Saether, Mr. Simon Sivertsen                         1307       3    male
# Ware, Mr. Frederick                                  1308       3    male
# Peter, Master. Michael J                             1309       3    male
#
#                                                Age  SibSp  Parch  \
# ...

# %%
test.loc['Myles, Mr. Thomas Francis']
# Out:
# PassengerId       894
# Pclass              2
# Sex              male
# Age                62
# SibSp               0
# Parch               0
# Ticket         240276
# Fare           9.6875
# Cabin             NaN
# Embarked            Q
# Name: Myles, Mr. Thomas Francis, dtype: object

# %%
test.reset_index(inplace=True)

# %%
test
# Out:
#      index                                          Name  PassengerId  Pclass  \
# 0        0                              Kelly, Mr. James          892       3
# 1        1              Wilkes, Mrs. James (Ellen Needs)          893       3
# 2        2                     Myles, Mr. Thomas Francis          894       2
# 3        3                              Wirz, Mr. Albert          895       3
# 4        4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3
# ..     ...                                           ...          ...     ...
# 413    413                            Spector, Mr. Woolf         1305       3
# 414    414                  Oliva y Ocana, Dona. Fermina         1306       1
# 415    415                  Saether, Mr. Simon Sivertsen         1307       3
# 416    416                           Ware, Mr. Frederick         1308       3
# 417    417                      Peter, Master. Michael J         1309       3
#
# ...
